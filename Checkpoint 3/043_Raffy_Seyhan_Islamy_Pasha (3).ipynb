# %% [markdown]
# #**Business Understanding**

# %% [markdown]
# ##**Business Objective**

# %% [markdown]
# Tujuan utama proyek ini adalah untuk memahami faktor-faktor yang mempengaruhi efisiensi tidur guna meningkatkan kualitas tidur masyarakat. Analisis ini mencakup pengaruh usia, jenis kelamin, kebiasaan konsumsi kafein dan alkohol, status merokok, serta frekuensi olahraga terhadap efisiensi tidur. Dengan memahami faktor-faktor ini, dapat dikembangkan strategi untuk meningkatkan kualitas tidur secara optimal.

# %% [markdown]
# ##**Assess Situation**

# %% [markdown]
# Situasi yang mendasari analisis ini berkaitan dengan pemahaman terhadap kualitas tidur serta faktor-faktor yang memengaruhinya. Dalam kehidupan modern, banyak individu mengalami gangguan tidur akibat berbagai faktor seperti gaya hidup, stres, konsumsi kafein dan alkohol, serta kebiasaan olahraga. Analisis data ini bertujuan untuk mengidentifikasi pola tidur yang sehat dengan mengevaluasi durasi tidur, efisiensi tidur, serta kebiasaan yang dapat mempengaruhi kualitas istirahat seseorang.

# %% [markdown]
# ##**Data Mining Goals**

# %% [markdown]
# Mengidentifikasi hubungan antara faktor gaya hidup dan efisiensi tidur dengan menganalisis pola tidur berdasarkan usia, jenis kelamin, konsumsi kafein dan alkohol, kebiasaan merokok, serta frekuensi olahraga. Tujuannya adalah untuk menemukan pola yang dapat digunakan untuk memberikan rekomendasi guna meningkatkan kualitas tidur individu.

# %% [markdown]
# ##**Project Plan**

# %% [markdown]
# Langkah pertama dalam proses ini adalah menganalisis data untuk memahami pola tidur dan faktor-faktor yang memengaruhi efisiensi tidur seseorang. Dari hasil analisis ini, data akan digunakan sebagai bahan edukasi untuk meningkatkan kesadaran masyarakat tentang pentingnya tidur yang berkualitas. Edukasi ini mencakup berbagai aspek, seperti faktor-faktor yang dapat memengaruhi kualitas tidur, termasuk konsumsi kafein dan alkohol, kebiasaan olahraga, serta pola tidur yang tidak teratur. Selain itu, informasi yang diperoleh juga dapat digunakan untuk memberikan rekomendasi mengenai cara meningkatkan kualitas tidur, seperti menjaga rutinitas tidur yang konsisten, menciptakan lingkungan tidur yang nyaman, dan menghindari kebiasaan yang dapat mengganggu istirahat. Dengan memahami dan menerapkan kebiasaan tidur yang lebih sehat, diharapkan individu dapat meningkatkan kesejahteraan fisik dan mental mereka, serta mengurangi risiko gangguan kesehatan yang berkaitan dengan kurang tidur.

# %% [markdown]
# #**MINPRO 2**

# %% [markdown]
# **LINK DATASET: https://www.kaggle.com/datasets/equilibriumm/sleep-efficiency**

# %%
import pandas as pd

# %%
df = pd.read_csv("Sleep_Efficiency.csv")

df
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %% [markdown]
# #**Data Understanding**

# %% [markdown]
# ##**Struktur Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup time             452 non-null    object
#  5   Sleep duration          452 non-null    float64
#  6   Sleep efficiency        452 non-null    float64
#  7   REM sleep percentage    452 non-null    int64
#  8   Deep sleep percentage   452 non-null    int64
#  9   Light sleep percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine consumption    427 non-null    float64
#  12  Alcohol consumption     438 non-null    float64
#  13  Smoking status          452 non-null    object
# ...

# %% [markdown]
# ##**Statistika Deskriptif**

# %%
df.describe()
# Out:
#                ID         Age  Sleep duration  Sleep efficiency  \
# count  452.000000  452.000000      452.000000        452.000000
# mean   226.500000   40.285398        7.465708          0.788916
# std    130.625419   13.172250        0.866625          0.135237
# min      1.000000    9.000000        5.000000          0.500000
# 25%    113.750000   29.000000        7.000000          0.697500
# 50%    226.500000   40.000000        7.500000          0.820000
# 75%    339.250000   52.000000        8.000000          0.900000
# max    452.000000   69.000000       10.000000          0.990000
#
#        REM sleep percentage  Deep sleep percentage  Light sleep percentage  \
# count            452.000000             452.000000              452.000000
# mean              22.615044              52.823009               24.561947
# std                3.525963              15.654235               15.313665
# min               15.000000              18.000000                7.000000
# ...

# %% [markdown]
# ##**Korelasi**

# %%
df.corr(numeric_only=True)
# Out:
#                               ID       Age  Sleep duration  Sleep efficiency  \
# ID                      1.000000  0.021310        0.014333         -0.025624
# Age                     0.021310  1.000000       -0.062462          0.098357
# Sleep duration          0.014333 -0.062462        1.000000         -0.027467
# Sleep efficiency       -0.025624  0.098357       -0.027467          1.000000
# REM sleep percentage    0.051636  0.042091       -0.015940          0.062362
# Deep sleep percentage  -0.047300  0.021730       -0.037304          0.787335
# Light sleep percentage  0.036463 -0.031905        0.041804         -0.819204
# Awakenings             -0.056447 -0.017789        0.004939         -0.564979
# Caffeine consumption   -0.059594 -0.171460       -0.014802          0.065082
# Alcohol consumption     0.115352  0.047188       -0.046243         -0.389624
# Exercise frequency      0.024640  0.072308       -0.068272          0.259563
#
# ...

# %% [markdown]
# #**Data Preparation**

# %% [markdown]
# ##**Missing Values**

# %% [markdown]
# **Melihat data kosong**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# ID                        0.0
# Age                       0.0
# Gender                    0.0
# Bedtime                   0.0
# Wakeup time               0.0
# Sleep duration            0.0
# Sleep efficiency          0.0
# REM sleep percentage      0.0
# Deep sleep percentage     0.0
# Light sleep percentage    0.0
# Awakenings                0.0
# Caffeine consumption      0.0
# Alcohol consumption       0.0
# Smoking status            0.0
# Exercise frequency        0.0
# dtype: float64

# %% [markdown]
# **Melihat data yang kosong**

# %%
df[df['Awakenings'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Age, Gender, Bedtime, Wakeup time, Sleep duration, Sleep efficiency, REM sleep percentage, Deep sleep percentage, Light sleep percentage, Awakenings, Caffeine consumption, Alcohol consumption, Smoking status, Exercise frequency]
# Index: []

# %%
df[df['Caffeine consumption'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Age, Gender, Bedtime, Wakeup time, Sleep duration, Sleep efficiency, REM sleep percentage, Deep sleep percentage, Light sleep percentage, Awakenings, Caffeine consumption, Alcohol consumption, Smoking status, Exercise frequency]
# Index: []

# %%
df[df['Alcohol consumption'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Age, Gender, Bedtime, Wakeup time, Sleep duration, Sleep efficiency, REM sleep percentage, Deep sleep percentage, Light sleep percentage, Awakenings, Caffeine consumption, Alcohol consumption, Smoking status, Exercise frequency]
# Index: []

# %%
df[df['Exercise frequency'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Age, Gender, Bedtime, Wakeup time, Sleep duration, Sleep efficiency, REM sleep percentage, Deep sleep percentage, Light sleep percentage, Awakenings, Caffeine consumption, Alcohol consumption, Smoking status, Exercise frequency]
# Index: []

# %% [markdown]
# **Penanganan**

# %%
df['Awakenings'] = df['Awakenings'].fillna(df['Awakenings'].dropna().mean())

# %%
df['Caffeine consumption'] = df['Caffeine consumption'].fillna(df['Caffeine consumption'].dropna().mean())

# %%
df['Alcohol consumption'] = df['Alcohol consumption'].fillna(df['Alcohol consumption'].dropna().mean())

# %%
df['Exercise frequency'] = df['Exercise frequency'].fillna(df['Exercise frequency'].dropna().mean())

# %% [markdown]
# **Pengecekan Ulang**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# ID                        0.0
# Age                       0.0
# Gender                    0.0
# Bedtime                   0.0
# Wakeup time               0.0
# Sleep duration            0.0
# Sleep efficiency          0.0
# REM sleep percentage      0.0
# Deep sleep percentage     0.0
# Light sleep percentage    0.0
# Awakenings                0.0
# Caffeine consumption      0.0
# Alcohol consumption       0.0
# Smoking status            0.0
# Exercise frequency        0.0
# dtype: float64

# %% [markdown]
# ##**Duplicated Value**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Age, Gender, Bedtime, Wakeup time, Sleep duration, Sleep efficiency, REM sleep percentage, Deep sleep percentage, Light sleep percentage, Awakenings, Caffeine consumption, Alcohol consumption, Smoking status, Exercise frequency]
# Index: []

# %% [markdown]
# ##**Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                   Persentase Outliers
# ID                                 0.000000
# Age                                0.000000
# Sleep duration                     3.539823
# Sleep efficiency                   0.000000
# REM sleep percentage               0.000000
# Deep sleep percentage             13.274336
# Light sleep percentage             0.442478
# Awakenings                         0.000000
# Caffeine consumption               0.884956
# Alcohol consumption                0.000000
# Exercise frequency                 0.000000

# %%
columns_to_impute = ["Sleep duration", "Deep sleep percentage","Caffeine consumption","Light sleep percentage"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)
# Out:
# <ipython-input-31-68830b3a61e8>:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[70.    28.    70.    26.125 55.    60.    26.125 52.    55.    37.
#  57.    60.    58.    26.125 32.    55.    26.125 26.125 67.    52.
#  75.    58.    60.    65.    75.    72.    55.    60.    26.125 60.
#  26.125 30.    26.125 53.    60.    26.125 72.    56.    60.    26.125
#  58.    67.    26.125 60.    65.    63.    57.    60.    60.    55.
#  57.    59.    35.    35.    70.    70.    55.    58.    65.    60.
#  60.    60.    67.    55.    70.    63.    70.    72.    70.    35.
#  26.125 62.    35.    60.    58.    28.    60.    70.    70.    60.
#  67.    67.    60.    57.    26.125 65.    57.    58.    60.    56.
#  60.    55.    35.    58.    58.    67.    55.    57.    67.    70.
#  55.    67.    60.    32.    60.    57.    26.125 63.    63.    57.
#  57.    65.    65.    67.    63.    26.125 57.    35.    62.    70.
# ...

# %% [markdown]
# ##**Inconsistent Values**

# %%
df["Gender"].unique()
df["Smoking status"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df[df["Sleep duration"] < 0]
# Out:
# Empty DataFrame
# Columns: [ID, Age, Gender, Bedtime, Wakeup time, Sleep duration, Sleep efficiency, REM sleep percentage, Deep sleep percentage, Light sleep percentage, Awakenings, Caffeine consumption, Alcohol consumption, Smoking status, Exercise frequency]
# Index: []

# %%
df[~df["Gender"].isin(["Male", "Female"])]
df[~df["Smoking status"].isin(["Yes", "No"])]
# Out:
# Empty DataFrame
# Columns: [ID, Age, Gender, Bedtime, Wakeup time, Sleep duration, Sleep efficiency, REM sleep percentage, Deep sleep percentage, Light sleep percentage, Awakenings, Caffeine consumption, Alcohol consumption, Smoking status, Exercise frequency]
# Index: []

# %% [markdown]
# ##**Construct Data**

# %%
df["Healthy Sleep Time"] = df["Sleep duration"].apply(lambda x: "Yes" if x > 6 else "No")

# %%
df.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                 70.000
# 1              0.66                    19                 28.000
# 2              0.89                    20                 70.000
# 3              0.51                    23                 26.125
# 4              0.76                    27                 55.000
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# ...

# %% [markdown]
# ##**Data Reduction**

# %%
df = df.drop('REM sleep percentage', axis=1)

# %%
df
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  Deep sleep percentage  \
# 0               6.0              0.88                 70.000
# 1               7.0              0.66                 28.000
# ...

# %% [markdown]
# # **MINPRO 3**

# %% [markdown]
# ##**Visualisasi Data**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  Deep sleep percentage  \
# 0               6.0              0.88                 70.000
# 1               7.0              0.66                 28.000
# ...

# %% [markdown]
# ##**Heatmap**

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap')
plt.show()

# %% [markdown]
# Dari heatmap ini dapat kita lihat jika deep sleep percentage sangat mempengaruhi sleep efficiency karena jika seseorang menghabiskan banyak waktu pada deepsleep maka kemungkinan mereka terbangun di malam hari sangat kecil dan hal itulah yang membuat sleep efficiency juga meningkat

# %% [markdown]
# ##**Lama Waktu Tidur**

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Sleep duration', hue='Gender', multiple='dodge', kde=True)
plt.title('Waktu tidur berdasarkan gender')
plt.xlabel('Waktu Tidur')
plt.ylabel('Banyak orang')
plt.show()

# %% [markdown]
# Dari histogram ini terlihat bahwa rata rata orang tidur 7-8 jam dan hampir tidak ada perbedaan dalam jam tidur antara perempuan dan laki laki

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sleep duration', y='Caffeine consumption', data=df, color="blue", alpha=0.5)
plt.title('Hubungan antara Waktu Tidur dan Konsumsi Kafein')
plt.xlabel('Waktu Tidur')
plt.ylabel('Konsumsi Kafeine')
plt.show()

# %% [markdown]
# Dari grafik ini dapat kita lihat bahwa semua waktu tidur dari yang rendah ke yang tinggi mempunyai jumlah konsumsi kafein yang bervariasi, hal ini menunjukan meskipun ada yang mengonsumsi kafein dalam jumlah tinggi, kebanyakan dari mereka masih mempunyai tidur yang cukup

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Sleep duration', data=df, color="blue", alpha=0.5)
plt.title('Hubungan antara Waktu Tidur dan Umur')
plt.xlabel('Umur')
plt.ylabel('Waktu Tidur')
plt.show()

# %% [markdown]
# Dari grafik ini dapat kita lihat bahwa semua usia memiliki jumlah tidur yang beragam dari yang sebentar sampai yang lama, dari grafik ini juga tidak menunjukan bahwa usia memiliki hubungan yang kuat dengan waktu tidur

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sleep duration', y='Alcohol consumption', data=df, color="blue", alpha=0.5)
plt.title('Hubungan antara Waktu Tidur dan Konsumsi Alkohol')
plt.xlabel('Waktu Tidur')
plt.ylabel('Konsumsi Alkohol')
plt.show()

# %% [markdown]
# Titik titik tersebar jelas menunjukan bahwa alkohol tidak mempengaruhi jam tidur

# %% [markdown]
# kesimpulan:Berdasarkan analisis data yang telah dilakukan, tidak ditemukan hubungan yang signifikan antara faktor-faktor seperti konsumsi kafein, konsumsi alkohol, usia, dan gender terhadap durasi tidur. Mayoritas individu dalam dataset ini tidur dalam rentang 7–8 jam, terlepas dari perbedaan dalam pola konsumsi.
